# %%
import os
import uuid
os.environ["CUDA_VISIBLE_DEVICES"] = "0"


from IPython.display import Audio
import nltk  # we'll use this to split into sentences
import numpy as np

from bark.generation import (
    generate_text_semantic,
    preload_models,
)
from bark.api import semantic_to_waveform
from bark import generate_audio, SAMPLE_RATE
from scipy.io.wavfile import write as write_wav
from pydub import AudioSegment

# %%
preload_models()
# Out:
# No GPU being used. Careful, inference might be very slow!

# %%
text_prompt = """
    ♪  ♪
    ♪  ♪
    ♪  ♪
"""

for i in range(10):
    filename = str(uuid.uuid4())
    print (filename)
    audio_array = generate_audio(text_prompt)

    # generation_duration_s = time.time() - t0
    audio_duration_s = audio_array.shape[0] / SAMPLE_RATE

    # print(f"took {generation_duration_s:.0f}s to generate {audio_duration_s:.0f}s of audio")

    Audio(audio_array, rate=SAMPLE_RATE)

    write_wav("../wav_gen/" + filename + ".wav", SAMPLE_RATE, audio_array)

    # Load the WAV file
    wav_file = AudioSegment.from_file("../wav_gen/" + filename + ".wav", format="wav")

    # Export it as an MP3 file
    wav_file.export("../mp3_gen/"+ filename +".mp3", format="mp3")
# Out:
# 9d001550-09ee-4443-b9d6-a082354577f7
# 100%|██████████| 714/714 [03:45<00:00,  3.17it/s]
# 100%|██████████| 36/36 [18:30<00:00, 30.84s/it]
# d372ea50-3797-4ca5-8131-55ded69f6bb1
# 100%|██████████| 697/697 [05:47<00:00,  2.01it/s]
# 100%|██████████| 35/35 [20:19<00:00, 34.83s/it]
# d2de0d73-e868-414b-b0ae-48ce4a42d341
# 100%|██████████| 660/660 [41:32<00:00,  3.78s/it]
# 100%|██████████| 34/34 [1:46:03<00:00, 187.15s/it]
# ed14831b-dedd-450b-b3f4-8b553ccde636
# 100%|██████████| 735/735 [1:11:44<00:00,  5.86s/it]
# 100%|██████████| 37/37 [2:47:03<00:00, 270.91s/it]
# 07661217-2d19-4da9-bb22-5dded6b11130
# 100%|██████████| 698/698 [1:23:25<00:00,  7.17s/it]
# 100%|██████████| 35/35 [2:20:16<00:00, 240.47s/it]
# 01162dad-d5bc-4e9d-ab6d-221e2b85a810
# 100%|██████████| 554/554 [03:46<00:00,  2.45it/s]
# 100%|██████████| 28/28 [16:14<00:00, 34.79s/it]
# e6c9377e-0395-4957-9019-7252bf9541b8
# 100%|██████████| 683/683 [09:30<00:00,  1.20it/s]
# 100%|██████████| 35/35 [34:17<00:00, 58.80s/it]
# 8120b075-01e2-43d7-b951-70fe21a1cb55
# 100%|██████████| 696/696 [05:06<00:00,  2.27it/s]

# %%
text_prompt = """
    ♪ I see your monsters, I see your pain, Tell me your problems, I'll chase them away ♪
"""

for i in range(10):
    filename = str(uuid.uuid4())
    print (filename)
    audio_array = generate_audio(text_prompt)

    # generation_duration_s = time.time() - t0
    audio_duration_s = audio_array.shape[0] / SAMPLE_RATE

    # print(f"took {generation_duration_s:.0f}s to generate {audio_duration_s:.0f}s of audio")

    Audio(audio_array, rate=SAMPLE_RATE)

    write_wav("../wav_gen/" + filename + ".wav", SAMPLE_RATE, audio_array)

    # Load the WAV file
    wav_file = AudioSegment.from_file("../wav_gen/" + filename + ".wav", format="wav")

    # Export it as an MP3 file
    wav_file.export("../mp3_gen/"+ filename +".mp3", format="mp3")
# Out:
# 48ed863f-08e0-4128-a434-6dcb88db8b66
#   0%|          | 0/768 [00:00<?, ?it/s]
#  13%|█▎        | 99/768 [00:08<00:49, 13.63it/s]

# %%
text_prompt = """
    I have a silky smooth voice, and today I will tell you about 
    the exercise regimen of the common sloth.
"""
audio_array = generate_audio(text_prompt, history_prompt="en_speaker_1")
# Out:
# 100%|██████████| 382/382 [00:26<00:00, 14.65it/s]
# 100%|██████████| 20/20 [01:52<00:00,  5.63s/it]

# %%
text_prompt = """
    ♪ It's been a long day without you, my friend And I'll tell you all about it when I see you again, My name's Dustin Pro, My name's Dustin Pro ♪
    ♪ It's been a long day without you, my friend And I'll tell you all about it when I see you again, My name's Dustin Pro, My name's Dustin Pro ♪
"""
audio_array = generate_audio(text_prompt)
# Out:
# 100%|██████████| 718/718 [01:05<00:00, 10.92it/s]
# 100%|██████████| 36/36 [04:22<00:00,  7.28s/it]

# %%
text_prompt = """
    ♪ I’m hurting baby, I’m broken down, I need your loving, Loving, I need it no ♪
    ♪ When I’m without you, I’m something weak ♪
"""
audio_array = generate_audio(text_prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/dustin/Desktop/voice-generation/notebooks/long_form_generation.ipynb Cell 5 line <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/voice-generation/notebooks/long_form_generation.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> text_prompt = """
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/voice-generation/notebooks/long_form_generation.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     ♪ I’m hurting baby, I’m broken down, I need your loving, Loving, I need it no ♪
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/voice-generation/notebooks/long_form_generation.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     ♪ When I’m without you, I’m something weak ♪
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/voice-generation/notebooks/long_form_generation.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> """
# ----> <a href='vscode-notebook-cell:/Users/dustin/Desktop/voice-generation/notebooks/long_form_generation.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> audio_array = generate_audio(text_prompt)
#
# NameError: name 'generate_audio' is not defined

# %%
# generation_duration_s = time.time() - t0
audio_duration_s = audio_array.shape[0] / SAMPLE_RATE

# print(f"took {generation_duration_s:.0f}s to generate {audio_duration_s:.0f}s of audio")

Audio(audio_array, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.io.wavfile import write as write_wav
from pydub import AudioSegment

write_wav("output2.wav", SAMPLE_RATE, audio_array)

# Load the WAV file
wav_file = AudioSegment.from_file("output2.wav", format="wav")

# Export it as an MP3 file
wav_file.export("../output1.mp3", format="mp3")

# %%
text_prompt = """
    ♪ I’m hurting baby, I’m broken down, I need your loving, Loving ♪
    ♪ I need it now ♪
"""
audio_array = generate_audio(text_prompt)
# Out:
# 100%|██████████| 662/662 [00:53<00:00, 12.30it/s]
# 100%|██████████| 34/34 [03:26<00:00,  6.06s/it]

# %%
# generation_duration_s = time.time() - t0
audio_duration_s = audio_array.shape[0] / SAMPLE_RATE

# print(f"took {generation_duration_s:.0f}s to generate {audio_duration_s:.0f}s of audio")

Audio(audio_array, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.io.wavfile import write as write_wav
from pydub import AudioSegment

write_wav("output2.wav", SAMPLE_RATE, audio_array)

# Load the WAV file
wav_file = AudioSegment.from_file("output2.wav", format="wav")

# Export it as an MP3 file
wav_file.export("../output2.mp3", format="mp3")

# %%
# generate audio from text
text_prompt = """
My name is Dustin, I step up to the mic, ready to ignite,
Spittin' fire in the booth, every word so tight, sixteen teeth on the mic, Yoyo.
"""
audio_array = generate_audio(text_prompt)

# play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# 100%|██████████| 699/699 [00:54<00:00, 12.93it/s]
# 100%|██████████| 35/35 [03:39<00:00,  6.27s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.io.wavfile import write as write_wav
from pydub import AudioSegment

write_wav("output2.wav", SAMPLE_RATE, audio_array)

# Load the WAV file
wav_file = AudioSegment.from_file("output2.wav", format="wav")

# Export it as an MP3 file
wav_file.export("../output1.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='../output2.mp3'>

# %%
from pydub import AudioSegment

audio_data = audio_array

# Convert the audio data to an AudioSegment object
audio_segment = AudioSegment(
    audio_data.tobytes(),
    frame_rate=SAMPLE_RATE,
    sample_width= 
    # sample_width=audio_data.itemsize,
    channels=1  # Mono audio
)

# Save the audio as an MP3 file
audio_segment.export("output1.mp3", format="mp3")
# Out:
# ---------------------------------------------------------------------------
# MissingAudioParameter                     Traceback (most recent call last)
# /Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb Cell 7 line <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> audio_data = audio_array
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=4'>5</a> # Convert the audio data to an AudioSegment object
# ----> <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=5'>6</a> audio_segment = AudioSegment(
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=6'>7</a>     audio_data.tobytes(),
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=7'>8</a>     frame_rate=SAMPLE_RATE,
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=8'>9</a>
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=9'>10</a>     # sample_width=audio_data.itemsize,
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=10'>11</a>     channels=1  # Mono audio
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=11'>12</a> )
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=13'>14</a> # Save the audio as an MP3 file
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X40sZmlsZQ%3D%3D?line=14'>15</a> audio_segment.export("output1.mp3", format="mp3")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/lib/python3.9/site-packages/pydub/audio_segment.py:194, in AudioSegment.__init__(self, data, *args, **kwargs)
#     192 # prevent partial specification of arguments
#     193 if any(audio_params) and None in audio_params:
# --> 194     raise MissingAudioParameter("Either all audio parameters or no parameter must be specified")
#     196 # all arguments are given
#     197 elif self.sample_width is not None:
#
# MissingAudioParameter: Either all audio parameters or no parameter must be specified

# %%
# generate audio from text
text_prompt = """
    Hey, have you heard about this new text-to-audio model called "Bark"? 
    Apparently, it's the most realistic and natural-sounding text-to-audio model 
    out there right now. People are saying it sounds just like a real person speaking. 
    I think it uses advanced machine learning algorithms to analyze and understand the 
    nuances of human speech, and then replicates those nuances in its own speech output. 
    It's pretty impressive, and I bet it could be used for things like audiobooks or podcasts. 
    In fact, I heard that some publishers are already starting to use Bark to create audiobooks. 
    It would be like having your own personal voiceover artist. I really think Bark is going to 
    be a game-changer in the world of text-to-audio technology.
"""
audio_array = generate_audio(text_prompt)

# play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# 100%|██████████| 627/627 [00:46<00:00, 13.51it/s]
# 100%|██████████| 32/32 [03:24<00:00,  6.41s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Simple Long-Form Generation
# We split longer text into sentences using `nltk` and generate the sentences one by one.

# %%
script = """
Hey, have you heard about this new text-to-audio model called "Bark"? 
Apparently, it's the most realistic and natural-sounding text-to-audio model 
out there right now. People are saying it sounds just like a real person speaking. 
I think it uses advanced machine learning algorithms to analyze and understand the 
nuances of human speech, and then replicates those nuances in its own speech output. 
It's pretty impressive, and I bet it could be used for things like audiobooks or podcasts. 
In fact, I heard that some publishers are already starting to use Bark to create audiobooks. 
It would be like having your own personal voiceover artist. I really think Bark is going to 
be a game-changer in the world of text-to-audio technology.
""".replace("\n", " ").strip()

# %%
sentences = nltk.sent_tokenize(script)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb Cell 6 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> sentences = nltk.sent_tokenize(script)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/lib/python3.9/site-packages/nltk/tokenize/__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/lib/python3.9/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/lib/python3.9/site-packages/nltk/data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/lib/python3.9/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/Users/dustin/nltk_data'
#     - '/opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/nltk_data'
#     - '/opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/share/nltk_data'
#     - '/opt/homebrew/Caskroom/miniconda/base/envs/nlp_env/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
SPEAKER = "v2/en_speaker_6"
silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence

pieces = []
for sentence in sentences:
    audio_array = generate_audio(sentence, history_prompt=SPEAKER)
    pieces += [audio_array, silence.copy()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb Cell 7 line <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> pieces = []
# ----> <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> for sentence in sentences:
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     audio_array = generate_audio(sentence, history_prompt=SPEAKER)
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>     pieces += [audio_array, silence.copy()]
#
# NameError: name 'sentences' is not defined

# %%
Audio(np.concatenate(pieces), rate=SAMPLE_RATE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb Cell 8 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> Audio(np.concatenate(pieces), rate=SAMPLE_RATE)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %% [markdown]
# # $ \\ $

# %% [markdown]
# # Advanced Long-Form Generation
# Somtimes Bark will hallucinate a little extra audio at the end of the prompt.
# We can solve this issue by lowering the threshold for bark to stop generating text.
# We use the `min_eos_p` kwarg in `generate_text_semantic`

# %%
GEN_TEMP = 0.6
SPEAKER = "v2/en_speaker_6"
silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence

pieces = []
for sentence in sentences:
    semantic_tokens = generate_text_semantic(
        sentence,
        history_prompt=SPEAKER,
        temp=GEN_TEMP,
        min_eos_p=0.05,  # this controls how likely the generation is to end
    )

    audio_array = semantic_to_waveform(semantic_tokens, history_prompt=SPEAKER,)
    pieces += [audio_array, silence.copy()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb Cell 12 line <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> pieces = []
# ----> <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> for sentence in sentences:
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>     semantic_tokens = generate_text_semantic(
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>         sentence,
#       <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>         history_prompt=SPEAKER,
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a>         temp=GEN_TEMP,
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>         min_eos_p=0.05,  # this controls how likely the generation is to end
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a>     )
#      <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a>     audio_array = semantic_to_waveform(semantic_tokens, history_prompt=SPEAKER,)
#
# NameError: name 'sentences' is not defined

# %%
Audio(np.concatenate(pieces), rate=SAMPLE_RATE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb Cell 13 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/dustin/Desktop/Tech/bark/notebooks/long_form_generation.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> Audio(np.concatenate(pieces), rate=SAMPLE_RATE)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %% [markdown]
# # $ \\ $

# %% [markdown]
# # Make a Long-Form Dialog with Bark

# %% [markdown]
# ### Step 1: Format a script and speaker lookup

# %%
speaker_lookup = {"Samantha": "v2/en_speaker_9", "John": "v2/en_speaker_2"}

# Script generated by chat GPT
script = """
Samantha: Hey, have you heard about this new text-to-audio model called "Bark"?

John: No, I haven't. What's so special about it?

Samantha: Well, apparently it's the most realistic and natural-sounding text-to-audio model out there right now. People are saying it sounds just like a real person speaking.

John: Wow, that sounds amazing. How does it work?

Samantha: I think it uses advanced machine learning algorithms to analyze and understand the nuances of human speech, and then replicates those nuances in its own speech output.

John: That's pretty impressive. Do you think it could be used for things like audiobooks or podcasts?

Samantha: Definitely! In fact, I heard that some publishers are already starting to use Bark to create audiobooks. And I bet it would be great for podcasts too.

John: I can imagine. It would be like having your own personal voiceover artist.

Samantha: Exactly! I think Bark is going to be a game-changer in the world of text-to-audio technology."""
script = script.strip().split("\n")
script = [s.strip() for s in script if s]
script
# Out:
# ['Samantha: Hey, have you heard about this new text-to-audio model called "Bark"?',
#  "John: No, I haven't. What's so special about it?",
#  "Samantha: Well, apparently it's the most realistic and natural-sounding text-to-audio model out there right now. People are saying it sounds just like a real person speaking.",
#  'John: Wow, that sounds amazing. How does it work?',
#  'Samantha: I think it uses advanced machine learning algorithms to analyze and understand the nuances of human speech, and then replicates those nuances in its own speech output.',
#  "John: That's pretty impressive. Do you think it could be used for things like audiobooks or podcasts?",
#  'Samantha: Definitely! In fact, I heard that some publishers are already starting to use Bark to create audiobooks. And I bet it would be great for podcasts too.',
#  'John: I can imagine. It would be like having your own personal voiceover artist.',
#  'Samantha: Exactly! I think Bark is going to be a game-changer in the world of text-to-audio technology.']

# %% [markdown]
# ### Step 2: Generate the audio for every speaker turn

# %%
pieces = []
silence = np.zeros(int(0.5*SAMPLE_RATE))
for line in script:
    speaker, text = line.split(": ")
    audio_array = generate_audio(text, history_prompt=speaker_lookup[speaker], )
    pieces += [audio_array, silence.copy()]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 34.03it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 22/22 [00:08<00:00,  2.55it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 71.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 11/11 [00:04<00:00,  2.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 22.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 33/33 [00:13<00:00,  2.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 70.76it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 11/11 [00:04<00:00,  2.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 20.46it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 36/36 [00:14<00:00,  2.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 20.18it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 37/37 [00:14<00:00,  2.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 23.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 32/32 [00:12<00:00,  2.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 14/14 [00:05<00:00,  2.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 31.71it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 24/24 [00:09<00:00,  2.56it/s]

# %% [markdown]
# ### Step 3: Concatenate all of the audio and play it

# %%
Audio(np.concatenate(pieces), rate=SAMPLE_RATE)
